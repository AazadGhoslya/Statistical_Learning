# %%
# Session 1

# %%
#Exercise 2

#a
Regression
n =500
p = profit, number of employees, industry

#b
Classification
n = 20
p = price of the product, marketing budget, competition price

#c
Regression
n = 52
p = percent cahnge in all the markets.

# %%
#Exercise 10
library(MASS)
?Boston
# there are 506 Rows, 14 columns

# %%
#
pairs(Boston)
# Out:
# plot without title

# %%
plot(Boston$dis,Boston$age)
plot(Boston$tax,Boston$age)
plot(Boston$crim,Boston$age)
# Out:
# plot without title
# plot without title
# plot without title

# %%
hist(Boston$crim,breaks=20)
hist(Boston$tax,breaks=20)
hist(Boston$ptratio,breaks=20)
# Out:
# Plot with title "Histogram of Boston$crim"
# Plot with title "Histogram of Boston$tax"
# Plot with title "Histogram of Boston$ptratio"

# %%
subset(Boston, chas == 1)
# Out:
#     crim    zn indus chas nox    rm    age   dis    rad tax ptratio black
# 143 3.32105  0 19.58 1    0.8710 5.403 100.0 1.3216  5  403 14.7    396.90
# 153 1.12658  0 19.58 1    0.8710 5.012  88.0 1.6102  5  403 14.7    343.28
# 155 1.41385  0 19.58 1    0.8710 6.129  96.0 1.7494  5  403 14.7    321.02
# 156 3.53501  0 19.58 1    0.8710 6.152  82.6 1.7455  5  403 14.7     88.01
# 161 1.27346  0 19.58 1    0.6050 6.250  92.6 1.7984  5  403 14.7    338.92
# 163 1.83377  0 19.58 1    0.6050 7.802  98.2 2.0407  5  403 14.7    389.61
# 164 1.51902  0 19.58 1    0.6050 8.375  93.9 2.1620  5  403 14.7    388.45
# 209 0.13587  0 10.59 1    0.4890 6.064  59.1 4.2392  4  277 18.6    381.32
# 210 0.43571  0 10.59 1    0.4890 5.344 100.0 3.8750  4  277 18.6    396.90
# 211 0.17446  0 10.59 1    0.4890 5.960  92.1 3.8771  4  277 18.6    393.25
# 212 0.37578  0 10.59 1    0.4890 5.404  88.6 3.6650  4  277 18.6    395.24
# 213 0.21719  0 10.59 1    0.4890 5.807  53.8 3.6526  4  277 18.6    390.94
# ...

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %%
x = summary(Boston$medv)
x
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    5.00   17.02   21.20   22.53   25.00   50.00

# %%
x = subset(Boston, rm > 7)
x
# Out:
#     crim     zn   indus chas nox    rm    age   dis    rad tax ptratio black
# 3   0.02729   0.0  7.07 0    0.4690 7.185 61.1  4.9671 2   242 17.8    392.83
# 5   0.06905   0.0  2.18 0    0.4580 7.147 54.2  6.0622 3   222 18.7    396.90
# 41  0.03359  75.0  2.95 0    0.4280 7.024 15.8  5.4011 3   252 18.3    395.62
# 56  0.01311  90.0  1.22 0    0.4030 7.249 21.9  8.6966 5   226 17.9    395.93
# 65  0.01951  17.5  1.38 0    0.4161 7.104 59.5  9.2229 3   216 18.6    393.24
# 89  0.05660   0.0  3.41 0    0.4890 7.007 86.3  3.4217 2   270 17.8    396.90
# 90  0.05302   0.0  3.41 0    0.4890 7.079 63.1  3.4145 2   270 17.8    396.06
# 98  0.12083   0.0  2.89 0    0.4450 8.069 76.0  3.4952 2   276 18.0    396.90
# 99  0.08187   0.0  2.89 0    0.4450 7.820 36.9  3.4952 2   276 18.0    393.53
# 100 0.06860   0.0  2.89 0    0.4450 7.416 62.5  3.4952 2   276 18.0    396.90
# 162 1.46336   0.0 19.58 0    0.6050 7.489 90.8  1.9709 5   403 14.7    374.43
# ...

# %%
#Exrecise 3 
#3
#a = Option c
#b
x = 50 + 80 + .07 * 110 + 35 * 1 + .01 * 440 - 40
x
#c = False
# Out:
# [1] 137.1

# %%
#10
install.packages("ISLR")
# Out:
#   There is a binary version available but the source version is later:
#      binary source needs_compilation
# ISLR    1.2    1.4             FALSE
# installing the source package 'ISLR'

# %%
library(ISLR)

# %%
Carseats
# Out:
#     Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1    9.50 138        73    11          276        120   Bad       42  17
# 2   11.22 111        48    16          260         83   Good      65  10
# 3   10.06 113        35    10          269         80   Medium    59  12
# 4    7.40 117       100     4          466         97   Medium    55  14
# 5    4.15 141        64     3          340        128   Bad       38  13
# 6   10.81 124       113    13          501         72   Bad       78  16
# 7    6.63 115       105     0           45        108   Medium    71  15
# 8   11.85 136        81    15          425        120   Good      67  10
# 9    6.54 132       110     0          108        124   Medium    76  10
# 10   4.69 132       113     0          131        124   Medium    76  17
# 11   9.01 121        78     9          150        100   Bad       26  10
# 12  11.96 117        94     4          503         94   Good      50  13
# ...

# %%
attach(Carseats)
lm.fit = lm(Sales ~ Price+ Urban + US)
summary(lm.fit)
# Out:
# The following objects are masked from Carseats (pos = 3):
#
#     Advertising, Age, CompPrice, Education, Income, Population, Price,
#     Sales, ShelveLoc, Urban, US
#
# The following objects are masked from Carseats (pos = 4):
#
#     Advertising, Age, CompPrice, Education, Income, Population, Price,
#     Sales, ShelveLoc, Urban, US
# Call:
# lm(formula = Sales ~ Price + Urban + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# ...

# %%
Sales = 13.04 + (-0.054459) + (-0.021916) +1.200573

# %%
lm.fit1  = lm(Sales ~ Price+ US)
summary(lm.fit1)
# Out:
# Call:
# lm(formula = Sales ~ Price + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %%
confint(lm.fit1)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %%
#15
library(MASS)

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...
